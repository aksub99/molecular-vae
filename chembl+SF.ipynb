# %% [markdown]
# <a href="https://colab.research.google.com/github/aksub99/molecular-vae/blob/master/chembl%2BSF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data
import gzip
import pandas
import h5py
import numpy as np
from __future__ import print_function
import argparse
import os
import h5py
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn import model_selection

# %%
def one_hot_array(i, n):
    return map(int, [ix == i for ix in xrange(n)])

def one_hot_index(vec, charset):
    return map(charset.index, vec)

def from_one_hot_array(vec):
    oh = np.where(vec == 1)
    if oh[0].shape == (0, ):
        return None
    return int(oh[0][0])

def decode_smiles_from_indexes(vec, charset):
    return "".join(map(lambda x: charset[x], vec)).strip()

def load_dataset(filename, split = True):
    h5f = h5py.File(filename, 'r')
    if split:
        data_train = h5f['data_train'][:]
    else:
        data_train = None
    data_test = h5f['data_test'][:]
    charset =  h5f['charset'][:]
    h5f.close()
    if split:
        return (data_train, data_test, charset)
    else:
        return (data_test, charset)

# %%
class MolecularVAE(nn.Module):
    def __init__(self):
        super(MolecularVAE, self).__init__()

        self.conv_1 = nn.Conv1d(120, 9, kernel_size=9)
        self.conv_2 = nn.Conv1d(9, 9, kernel_size=9)
        self.conv_3 = nn.Conv1d(9, 10, kernel_size=11)
        self.linear_0 = nn.Linear(240, 435)
        self.linear_1 = nn.Linear(435, 292)
        self.linear_2 = nn.Linear(435, 292)

        self.linear_3 = nn.Linear(292, 292)
        self.gru = nn.GRU(292, 501, 3, batch_first=True)
        self.linear_4 = nn.Linear(501, 50)
        
        self.relu = nn.ReLU()
        self.softmax = nn.Softmax()

    def encode(self, x):
        x = self.relu(self.conv_1(x))
        x = self.relu(self.conv_2(x))
        x = self.relu(self.conv_3(x))
        x = x.view(x.size(0), -1)
        x = F.selu(self.linear_0(x))
        return self.linear_1(x), self.linear_2(x)

    def sampling(self, z_mean, z_logvar):
        epsilon = 1e-2 * torch.randn_like(z_logvar)
        return torch.exp(0.5 * z_logvar) * epsilon + z_mean

    def decode(self, z):
        z = F.selu(self.linear_3(z))
        z = z.view(z.size(0), 1, z.size(-1)).repeat(1, 120, 1)
        output, hn = self.gru(z)
        out_reshape = output.contiguous().view(-1, output.size(-1))
        y0 = F.softmax(self.linear_4(out_reshape), dim=1)
        y = y0.contiguous().view(output.size(0), -1, y0.size(-1))
        return y

    def forward(self, x):
        z_mean, z_logvar = self.encode(x)
        z = self.sampling(z_mean, z_logvar)
        return self.decode(z), z_mean, z_logvar

def vae_loss(x_decoded_mean, x, z_mean, z_logvar):
    xent_loss = F.binary_cross_entropy(x_decoded_mean, x, size_average=False)
    kl_loss = -0.5 * torch.sum(1 + z_logvar - z_mean.pow(2) - z_logvar.exp())
    return xent_loss + kl_loss

# %%
# !rm -R 'molecular-vae'
# !git clone https://github.com/aksub99/molecular-vae.git
# import zipfile
# zip_ref = zipfile.ZipFile('molecular-vae/data/processed.zip', 'r')
# zip_ref.extractall('molecular-vae/data/')
# zip_ref.close()

# !git clone https://aksub99:Ajak1999@github.com/aksub99/FissionNet.git

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
data_train, data_test, charset = load_dataset('drive/My Drive/chembl+SF/chembl_singlet_processed.h5')
data_train = torch.utils.data.TensorDataset(torch.from_numpy(data_train))
train_loader = torch.utils.data.DataLoader(data_train, batch_size=250, shuffle=True)

data_test = torch.utils.data.TensorDataset(torch.from_numpy(data_test))
test_loader = torch.utils.data.DataLoader(data_test, batch_size=250, shuffle=True)

print(charset)
print(len(charset))

torch.manual_seed(42)

epochs = 90
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# [' ' '#' '%' ')' '(' '+' '-' '/' '.' '1' '0' '3' '2' '5' '4' '7' '6' '9'
#  '8' '=' 'A' '@' 'C' 'B' 'F' 'I' 'H' 'K' 'L' 'O' 'N' 'P' 'S' 'T' '[' 'Z'
#  ']' '\\' 'a' 'c' 'b' 'e' 'i' 'l' 'o' 'n' 'p' 's' 'r' 't']
# 50

# %%
model = MolecularVAE().to(device)
optimizer = optim.Adam(model.parameters())

# %%
def train(epoch):
    model.train()
    train_loss = 0
    for batch_idx, data in enumerate(train_loader):
        data = data[0].to(device)
        optimizer.zero_grad()
        output, mean, logvar = model(data)
        
        if batch_idx==0:
              inp = data.cpu().numpy()
              outp = output.cpu().detach().numpy()
              lab = data.cpu().numpy()
              print("Input:")
              print(decode_smiles_from_indexes(map(from_one_hot_array, inp[0]), charset))
              print("Label:")
              print(decode_smiles_from_indexes(map(from_one_hot_array, lab[0]), charset))
              sampled = outp[0].reshape(1, 120, len(charset)).argmax(axis=2)[0]
              print("Output:")
              print(decode_smiles_from_indexes(sampled, charset))
        
        loss = vae_loss(output, data, mean, logvar)
        loss.backward()
        train_loss += loss
        optimizer.step()
#         if batch_idx % 100 == 0:
#             print(f'{epoch} / {batch_idx}\t{loss:.4f}')
    print('train', train_loss / len(train_loader.dataset))
    return train_loss / len(train_loader.dataset)
  
def test(epoch):
  with torch.no_grad():
      test_loss = 0.0
      for batch_idx, data in enumerate(test_loader):
          data = data[0].to(device)
          output, mean, logvar = model(data)
          loss = vae_loss(output, data, mean, logvar)
          test_loss += loss
      print('test', test_loss / len(test_loader.dataset))
      return test_loss / len(test_loader.dataset)

# %%
import matplotlib.pyplot as plt

train_loss_values = []
test_loss_values = []
for epoch in range(1, epochs + 1):
    train_loss = train(epoch)
    test_loss = test(epoch)
    train_loss_values.append(train_loss)
    test_loss_values.append(test_loss)
    if epoch % 5 == 0:
        plt.plot(np.array(train_loss_values), 'r')
        plt.plot(np.array(test_loss_values), 'b')
    if epoch % 2 == 0:
        torch.save(model.state_dict(), "drive/My Drive/chembl+SF/chembl+SF_{}.pth".format(epoch))
# Out:
# Input:
# Cc1nccn1CCCNC(=O)c2ccc(Cl)nc2
# Label:
# Cc1nccn1CCCNC(=O)c2ccc(Cl)nc2
# Output:
# 666]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
# /usr/local/lib/python2.7/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# train tensor(210.2584, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(170.2589, device='cuda:0')
# Input:
# CC(=CC(=O)c1cc(c2OCC(C)(C)c2c1)C(C)(C)C)C
# Label:
# CC(=CC(=O)c1cc(c2OCC(C)(C)c2c1)C(C)(C)C)C
# Output:
# CCCCCCCCCcccccccccccccccccccccccccc
# train tensor(172.3749, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(167.0728, device='cuda:0')
# Input:
# C[C@]12CCC3C(CC=C4C[C@@H](O)CC[C@]34C)C1CC[C@@H]2OC5CC5
# Label:
# C[C@]12CCC3C(CC=C4C[C@@H](O)CC[C@]34C)C1CC[C@@H]2OC5CC5
# Output:
# CCCCCCCCCCCCCCCCCCCCcccccccccccccccccccccccccccccccccccc
# train tensor(170.9138, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(166.5971, device='cuda:0')
# Input:
# [K+].[K+].C[C@]1(Cn2cc(nn2)C(=O)[O-])[C@@H](C3C(CC3=O)S1(=O)=O)C(=O)[O-]
# Label:
# [K+].[K+].C[C@]1(Cn2cc(nn2)C(=O)[O-])[C@@H](C3C(CC3=O)S1(=O)=O)C(=O)[O-]
# Output:
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCcccccccccccccccccccccc
# train tensor(166.5211, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(160.9691, device='cuda:0')
# Input:
# CCCC(OCCN1CCN(CCC(=O)O)CC1)c2ccccc2
# Label:
# CCCC(OCCN1CCN(CCC(=O)O)CC1)c2ccccc2
# Output:
# CCCCCCCCCCCCCCCccccccccccccccccCC
# train tensor(161.6375, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(159.3899, device='cuda:0')
# Input:
# C[C@@H](CC1CC=CC=C1)[N+](C)(C)CCCc2ccccc2
# Label:
# C[C@@H](CC1CC=CC=C1)[N+](C)(C)CCCc2ccccc2
# Output:
# CCCCcccccccccccccccccccccccccccccccccccc
# train tensor(162.1839, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(159.0412, device='cuda:0')
# Input:
# OC(=O)c1ccc2ccc(\C=C\c3cc(O)cc(O)c3)nc2c1O
# Label:
# OC(=O)c1ccc2ccc(\C=C\c3cc(O)cc(O)c3)nc2c1O
# Output:
# CCCCccccccccccccccccccccccccccccccccccccc
# train tensor(161.8149, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(158.1682, device='cuda:0')
# Input:
# CC(=O)NC1N=C(c2ccccc2)c3ccccc3N(CC(=O)NCc4onc(n4)c5ccccc5)C1=O
# Label:
# CC(=O)NC1N=C(c2ccccc2)c3ccccc3N(CC(=O)NCc4onc(n4)c5ccccc5)C1=O
# Output:
# CCCCccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# train tensor(162.4242, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(161.3070, device='cuda:0')
# Input:
# Cc1c(C)n(C[C@H]2CCCN2S(=O)(=O)C)c3ccc(cc13)C(=O)N4CCC(CC4)N5C(=O)OCc6ccccc56
# Label:
# Cc1c(C)n(C[C@H]2CCCN2S(=O)(=O)C)c3ccc(cc13)C(=O)N4CCC(CC4)N5C(=O)OCc6ccccc56
# Output:
# CCCCCCCCCCCCCCCCCCCCCCCCCccccccccccccccccccccccccccccccccccccccccccccccccccccc
# train tensor(159.3897, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(158.2116, device='cuda:0')
# Input:
# OC(=O)C(=O)\C=C(/O)\c1cccc(F)c1
# Label:
# OC(=O)C(=O)\C=C(/O)\c1cccc(F)c1
# Output:
# CC11ccccccccccccccccccccccccccc1
# train tensor(161.2967, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(166.7060, device='cuda:0')
# Input:
# CCCCN1C(=O)N(CCCC)c2nc(C)n(c2C1=O)S(=O)(=O)CCCCl
# Label:
# CCCCN1C(=O)N(CCCC)c2nc(C)n(c2C1=O)S(=O)(=O)CCCCl
# Output:
# CCCCccccCCCCccccccccccccccccccccCCCCCCCCCCCCCCOO
# train tensor(162.4116, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(177.2163, device='cuda:0')
# Input:
# CSc1c(Cl)cc(cc1Cl)N2N=CC(=O)NC2=O
# Label:
# CSc1c(Cl)cc(cc1Cl)N2N=CC(=O)NC2=O
# Output:
# CCCCCCCCCCCCCCCCCCCCCCCCCCCOO
# train tensor(161.6419, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(158.6049, device='cuda:0')
# Input:
# CCCN(CCC)C1Cc2cccn3ncc(C1)c23
# Label:
# CCCN(CCC)C1Cc2cccn3ncc(C1)c23
# Output:
# CC1Cccccccccccccccccccccccc
# train tensor(157.6701, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(157.2415, device='cuda:0')
# Input:
# CN1N=C(S/C/1=N/C(=O)CNCC(=O)O)S(=O)(=O)N
# Label:
# CN1N=C(S/C/1=N/C(=O)CNCC(=O)O)S(=O)(=O)N
# Output:
# CC(CccccccccCCCCCCCCCCCCCCCCCCCCCCCCCOO
# train tensor(156.4745, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(154.0459, device='cuda:0')
# Input:
# CC(C)c1cccc(C(C)C)c1OS(=O)(=O)NC(=O)Oc2c(F)cccc2F
# Label:
# CC(C)c1cccc(C(C)C)c1OS(=O)(=O)NC(=O)Oc2c(F)cccc2F
# Output:
# CC(Cccccccccccccccccccccccccccccccccccccccccccccc
# train tensor(156.3754, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(155.5722, device='cuda:0')
# Input:
# Clc1cccc(\C=C\2/NC(=O)NC2=O)c1
# Label:
# Clc1cccc(\C=C\2/NC(=O)NC2=O)c1
# Output:
# CCCCccccccccccccCCCCCCCCCCCCC
# train tensor(154.3051, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(153.3032, device='cuda:0')
# Input:
# Fc1ccccc1C2CC(=O)c3cc4OCOc4cc3N2
# Label:
# Fc1ccccc1C2CC(=O)c3cc4OCOc4cc3N2
# Output:
# Cc1ccccccccccccccccccccccccccccc1
# train tensor(152.8971, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(149.2572, device='cuda:0')
# Input:
# OC[C@H]1C(F)[C@H](C1CO)N2C=C(\C=C\I)C(=O)NC2=O
# Label:
# OC[C@H]1C(F)[C@H](C1CO)N2C=C(\C=C\I)C(=O)NC2=O
# Output:
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCOO
# train tensor(163.3481, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(156.5288, device='cuda:0')
# Input:
# CCCCCCCCCCCC(=O)O[C@H](CC=C(C)C)C1=CC(=O)c2c(O)ccc(O)c2C1=O
# Label:
# CCCCCCCCCCCC(=O)O[C@H](CC=C(C)C)C1=CC(=O)c2c(O)ccc(O)c2C1=O
# Output:
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC)))
# train tensor(157.1535, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(162.5233, device='cuda:0')
# Input:
# CC(C)(C)c1cc(\C=C\c2ccccc2C(=O)O)cc(c1O)C(C)(C)C
# Label:
# CC(C)(C)c1cc(\C=C\c2ccccc2C(=O)O)cc(c1O)C(C)(C)C
# Output:
# CCCCCCCCcccccccccccccccccccccccCCCCCCCCCCC)))
# train tensor(153.0838, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(153.4004, device='cuda:0')
# Input:
# N[C@@H]([C@H](O)[C@H](O)C(=O)O)C(=O)O
# Label:
# N[C@@H]([C@H](O)[C@H](O)C(=O)O)C(=O)O
# Output:
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCOOOO
# train tensor(150.2487, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(165.2786, device='cuda:0')
# Input:
# CC(C)(C)C(=O)OC1=COC(=CC1=O)COC(c2ccccc2)(c3ccccc3)c4ccccc4
# Label:
# CC(C)(C)C(=O)OC1=COC(=CC1=O)COC(c2ccccc2)(c3ccccc3)c4ccccc4
# Output:
# CCCCCCCCCCCCCCCCCCCCCCCCcccccccccccccccccccccccccccccccc
# train tensor(149.0385, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(145.6030, device='cuda:0')
# Input:
# OC(=O)C[C@H](NS(=O)(=O)Cc1ccccc1)C(=O)NCCc2ccccc2
# Label:
# OC(=O)C[C@H](NS(=O)(=O)Cc1ccccc1)C(=O)NCCc2ccccc2
# Output:
# CCCCCCCCCCCCCCCCCCCCCCcccccccccccccccccccccccccc
# train tensor(148.1811, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(145.7369, device='cuda:0')
# Input:
# COc1ccc(cc1)S(=O)(=O)N(Cc2cccc(F)c2F)[C@H](Cc3cccs3)C(=O)NO
# Label:
# COc1ccc(cc1)S(=O)(=O)N(Cc2cccc(F)c2F)[C@H](Cc3cccs3)C(=O)NO
# Output:
# COc1cccccccccccccccccccccccccccccccccccccccccccc))))))))))
# train tensor(146.2218, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(143.1087, device='cuda:0')
# Input:
# CC(C)(C)Sc1c(CC(C)(C)C(=O)O)n(Cc2ccc(Cl)cc2)c3ccc(OCc4ccc5ccccc5c4)cc13
# Label:
# CC(C)(C)Sc1c(CC(C)(C)C(=O)O)n(Cc2ccc(Cl)cc2)c3ccc(OCc4ccc5ccccc5c4)cc13
# Output:
# CC(CCCCCCCCCCCCCCCCccccccccccccccccccccccccccccccccccccccccccccccccccc
# train tensor(145.3746, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(142.2815, device='cuda:0')
# Input:
# CSc1ccc(cc1)c2cc3ncccc3c(NCCCN)n2
# Label:
# CSc1ccc(cc1)c2cc3ncccc3c(NCCCN)n2
# Output:
# Ccc1cccccccccccccccccccccCCCCCCC
# train tensor(144.6641, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(143.0084, device='cuda:0')
# Input:
# C[C@H]1CC2C3CC[C@](O)(C(=O)CN4CCN(CC4)c5ccccn5)[C@@]3(C)C[C@H](O)C2[C@@]6(C)C=CC(=O)C=C16
# Label:
# C[C@H]1CC2C3CC[C@](O)(C(=O)CN4CCN(CC4)c5ccccn5)[C@@]3(C)C[C@H](O)C2[C@@]6(C)C=CC(=O)C=C16
# Output:
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# train tensor(142.7567, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(139.7585, device='cuda:0')
# Input:
# CO[C@H]1C[C@@H](Oc2c(OC)c(OC)c3c(O[C@]45O[C@H](CC=C4C(=O)C(=C(OC)[C@@]35OC)OC)c6ccccc6)c12)c7ccccc7
# Label:
# CO[C@H]1C[C@@H](Oc2c(OC)c(OC)c3c(O[C@]45O[C@H](CC=C4C(=O)C(=C(OC)[C@@]35OC)OC)c6ccccc6)c12)c7ccccc7
# Output:
# CC(@@CCCCCCCCCCCCCCCccccccccCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCccccccccccccccccccccccccccccccccccc
# train tensor(142.2496, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(141.1606, device='cuda:0')
# Input:
# [Br-].COc1ccc2nccc([C@@H](O)[C@@H]3C[C@@H]4CC[N@@+]3(Cc5cc(c(OC)c(c5)C(C)(C)C)C(C)(C)C)C[C@@H]4C=C)c2c1
# Label:
# [Br-].COc1ccc2nccc([C@@H](O)[C@@H]3C[C@@H]4CC[N@@+]3(Cc5cc(c(OC)c(c5)C(C)(C)C)C(C)(C)C)C[C@@H]4C=C)c2c1
# Output:
# CC(C].CCCcccccccccccccCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCccccccccccccccccccccccCCCCCCCCCCCCCCCCC
# train tensor(141.6053, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(139.7172, device='cuda:0')
# Input:
# CC(C)Nc1nc(nc(Cl)c1C)N2CCN(C)CC2
# Label:
# CC(C)Nc1nc(nc(Cl)c1C)N2CCN(C)CC2
# Output:
# CCCCcccccccccccccCCCCCCCCCCCCCC2
# train tensor(139.5980, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(137.3616, device='cuda:0')
# Input:
# COC(=O)c1cn2c(COc3ccc(NC(=O)C)cc23)n1
# Label:
# COC(=O)c1cn2c(COc3ccc(NC(=O)C)cc23)n1
# Output:
# CC(C)))c1ccccccCCCCccccccccccc)))ccc
# train tensor(139.4880, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(135.9586, device='cuda:0')
# Input:
# CCCCCCCOc1ccc(CCC(N)(CO)CCCC)cc1
# Label:
# CCCCCCCOc1ccc(CCC(N)(CO)CCCC)cc1
# Output:
# CCCCCCCCc1ccc(CCCCCCCCCCCCCCCccc1
# train tensor(136.8401, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(134.9205, device='cuda:0')
# Input:
# Cc1oc(cn1)c2ccc(cc2)S(=O)(=O)Nc3ccc(CCNC[C@H](O)c4cccnc4)cc3
# Label:
# Cc1oc(cn1)c2ccc(cc2)S(=O)(=O)Nc3ccc(CCNC[C@H](O)c4cccnc4)cc3
# Output:
# Cc1cc((cccccccccccccccccccccccccccccccccccccccccccccccccccc
# train tensor(138.5426, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(136.3802, device='cuda:0')
# Input:
# C[C@@H]1[C@@H](C)C(=O)N(CCC[N+](C)(C)CCCCCCC[N+](C)(C)CCCN2C(=O)[C@@H](C)[C@H](C)C2=O)C1=O
# Label:
# C[C@@H]1[C@@H](C)C(=O)N(CCC[N+](C)(C)CCCCCCC[N+](C)(C)CCCN2C(=O)[C@@H](C)[C@H](C)C2=O)C1=O
# Output:
# CCC@@H@@CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# train tensor(135.8547, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(132.9848, device='cuda:0')
# Input:
# CCCN(CCC)C1CCc2cccc(OS(=O)(=O)C(F)(F)F)c2C1
# Label:
# CCCN(CCC)C1CCc2cccc(OS(=O)(=O)C(F)(F)F)c2C1
# Output:
# CCCCCCCCCCCCCccccc(CCCCCCCCC)))ccCCC((())
# train tensor(134.9289, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(132.5250, device='cuda:0')
# Input:
# Cc1ccccc1S(=O)(=O)N[C@@H](CNC(=O)C[C@@H]2CC(=NO2)c3ccc(cc3)C(=N)N)C(=O)O.OC(=O)C(F)(F)F
# Label:
# Cc1ccccc1S(=O)(=O)N[C@@H](CNC(=O)C[C@@H]2CC(=NO2)c3ccc(cc3)C(=N)N)C(=O)O.OC(=O)C(F)(F)F
# Output:
# Cc1ccc(cc1ccCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC((((((cccccccccccccc)))))))))))))))))((())))
# train tensor(134.7076, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(131.5075, device='cuda:0')
# Input:
# CC(C)c1cccc(NC(=O)c2ccc(cc2)C(=O)O)c1
# Label:
# CC(C)c1cccc(NC(=O)c2ccc(cc2)C(=O)O)c1
# Output:
# CC(C)c1ccccccCCOO)ccccccccccc))(()))
# train tensor(132.6469, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(130.9060, device='cuda:0')
# Input:
# CCN(CC)C(=O)[C@H]1CN(CC=C)[C@@H]2Cc3c[nH]c4cccc(C2=C1)c34
# Label:
# CCN(CC)C(=O)[C@H]1CN(CC=C)[C@@H]2Cc3c[nH]c4cccc(C2=C1)c34
# Output:
# CC1CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCccccccccccccccccccccc
# train tensor(132.0875, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(129.9568, device='cuda:0')
# Input:
# NCC(F)CON
# Label:
# NCC(F)CON
# Output:
# NCCC==OOO
# train tensor(131.4686, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(129.0837, device='cuda:0')
# Input:
# CC1C2Cc3ccc(O)cc3C1(C)CCN2CC4CC4
# Label:
# CC1C2Cc3ccc(O)cc3C1(C)CCN2CC4CC4
# Output:
# CC1CCCc2cccccccccCCCCCCCCCCCCCC4
# train tensor(130.4438, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(127.4774, device='cuda:0')
# Input:
# ON=C1CCN(CC1)c2c(F)cc3C(=O)C(=CN(C4CC4)c3c2F)C(=O)O
# Label:
# ON=C1CCN(CC1)c2c(F)cc3C(=O)C(=CN(C4CC4)c3c2F)C(=O)O
# Output:
# CC1CCCCCCCCCCCc2cc(CCCCCCCCCCCCC))))))cccccc))((())
# train tensor(129.3161, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(131.3861, device='cuda:0')
# Input:
# c1cnccn1
# Label:
# c1cnccn1
# Output:
# c1cccccc1
# train tensor(128.6970, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(127.0050, device='cuda:0')
# Input:
# CCC[C@H](CS[C@@H](CCc1ccccc1C(C)(C)O)c2cccc(\C=C\c3ccc4ccc(Cl)cc4n3)c2)C(=O)O
# Label:
# CCC[C@H](CS[C@@H](CCc1ccccc1C(C)(C)O)c2cccc(\C=C\c3ccc4ccc(Cl)cc4n3)c2)C(=O)O
# Output:
# CCCC[[@@@]CCCCCCCCcccccccccccccccccccccccccccccccCCCCCCCCCCCccccccccccccccc
# train tensor(127.4304, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(128.2348, device='cuda:0')
# Input:
# NC[C@H]1O[C@@H](O[C@@H](CNc2ccc(cc2)C3CCCCC3)[C@@H]4C[C@@H](O)[C@@H](O4)N5C=CC(=O)NC5=O)[C@H](O)[C@@H]1O.OC(=O)C(F)(F)F
# Label:
# NC[C@H]1O[C@@H](O[C@@H](CNc2ccc(cc2)C3CCCCC3)[C@@H]4C[C@@H](O)[C@@H](O4)N5C=CC(=O)NC5=O)[C@H](O)[C@@H]1O.OC(=O)C(F)(F)F
# Output:
# NC[C@H]][@@@@@CCCCCCCccccccccccccccccCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCOOOOOOOOCCC((((())FFF
# train tensor(126.3129, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(130.1133, device='cuda:0')
# Input:
# CCN(CC)C(=O)c1ccc(cc1)C(N2CCN(CCO)CC2)c3ccccc3
# Label:
# CCN(CC)C(=O)c1ccc(cc1)C(N2CCN(CCO)CC2)c3ccccc3
# Output:
# CCN(CCCCCCOOccccccccc)(CCCCCCCCCCCCCccccccc3
# train tensor(125.8417, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(124.1255, device='cuda:0')
# Input:
# CCN(CC)Cc1cc(Nc2cc(C)nc(Nc3nc4cc(Cl)c(Cl)cc4[nH]3)n2)ccc1OC
# Label:
# CCN(CC)Cc1cc(Nc2cc(C)nc(Nc3nc4cc(Cl)c(Cl)cc4[nH]3)n2)ccc1OC
# Output:
# CCN(CC)Ccc1cc(cCCccccccccccccccccccccccccccccccccnnnnn)))C
# train tensor(124.8770, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(124.0228, device='cuda:0')
# Input:
# Cc1ccc(cc1)c2nnc(O)c(C#N)c2c3ccc(C)cc3
# Label:
# Cc1ccc(cc1)c2nnc(O)c(C#N)c2c3ccc(C)cc3
# Output:
# Cc1ccc(cc1)cccccccccc)))))ccccccccccc3
# train tensor(123.4961, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(126.9842, device='cuda:0')
# Input:
# CC(C)(C)NC(=O)c1ccccc1C[C@@H](O)[C@H](Cc2ccccc2)NC(=O)[C@H](CS(=O)(=O)c3ccc(Cl)cc3)NS(=O)(=O)C
# Label:
# CC(C)(C)NC(=O)c1ccccc1C[C@@H](O)[C@H](Cc2ccccc2)NC(=O)[C@H](CS(=O)(=O)c3ccc(Cl)cc3)NS(=O)(=O)C
# Output:
# CC(C)(C)(C(O)c1ccccccccc)))(ccccccccccccccccccccccccccccccccccccccccccccccc((((()))))))))
# train tensor(123.5430, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(122.1009, device='cuda:0')
# Input:
# CCCCCn1c(c(C)c2cc(O)ccc12)c3ccc(O)cc3
# Label:
# CCCCCn1c(c(C)c2cc(O)ccc12)c3ccc(O)cc3
# Output:
# CCCCCc1ccccCcccccccccccccccccccc)))cc
# train tensor(122.1426, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(125.3750, device='cuda:0')
# Input:
# OC1=C2C(c3cccc(OC(F)(F)F)c3)n4nccc4N=C2CCC1
# Label:
# OC1=C2C(c3cccc(OC(F)(F)F)c3)n4nccc4N=C2CCC1
# Output:
# OC1=C)CCc2ccccccCCCCccccccccccccccc)))CCCC
# train tensor(121.5921, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(124.5580, device='cuda:0')
# Input:
# Clc1ccc(NC(=O)NCC=C(c2ccccc2)c3ccccc3)cc1
# Label:
# Clc1ccc(NC(=O)NCC=C(c2ccccc2)c3ccccc3)cc1
# Output:
# Clc1ccc(CCCCCCCCCCccccccccccccccccccc)cc
# train tensor(120.7160, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(124.8346, device='cuda:0')
# Input:
# COC(=O)CC(N1CCCCCC1)C(=O)Oc2c(OC)cccc2OC
# Label:
# COC(=O)CC(N1CCCCCC1)C(=O)Oc2c(OC)cccc2OC
# Output:
# COC(=O)CCCCCCCCCCCCCCCCCOOccccccccccCOO
# train tensor(119.0160, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(120.6314, device='cuda:0')
# Input:
# COc1ccc2[nH]c3c(C)c4ccnc(NCCCN5CCN(CCCN)CC5)c4cc3c2c1
# Label:
# COc1ccc2[nH]c3c(C)c4ccnc(NCCCN5CCN(CCCN)CC5)c4cc3c2c1
# Output:
# COc1ccc2cccccccccccccccCCCCCCCCCCCCCCCCCCccccccccccc
# train tensor(119.4061, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(121.2621, device='cuda:0')
# Input:
# CCN1C=C(C(=O)O)C(=O)c2cc(F)c(nc12)N3CCNCC3
# Label:
# CCN1C=C(C(=O)O)C(=O)c2cc(F)c(nc12)N3CCNCC3
# Output:
# CCN1CC()C(=O)N(CC=O)c2cc((ccccccc2CCCCCCCC3
# train tensor(118.0811, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(116.8008, device='cuda:0')
# Input:
# COc1ccc(Cn2c(CC(C)(C)CC(=O)O)nc3cc(F)ccc23)cc1
# Label:
# COc1ccc(Cn2c(CC(C)(C)CC(=O)O)nc3cc(F)ccc23)cc1
# Output:
# COc1ccc(CCCCCCCCCCCCCCCC))))))cccccccccccc)ccc
# train tensor(116.5490, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(119.1953, device='cuda:0')
# Input:
# Cc1ccc2c(c1)c(cn2c3ccc(F)cc3)C4CCN(CCN5CCNC5=O)CC4
# Label:
# Cc1ccc2c(c1)c(cn2c3ccc(F)cc3)C4CCN(CCN5CCNC5=O)CC4
# Output:
# Cc1ccc(cc1cccccccccccccccc)CCCCCCCCCCCCCCCCCCCCC5
# train tensor(117.5509, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(122.4257, device='cuda:0')
# Input:
# C=C1C(Oc2ccccc2C1=O)c3ccc4ccccc4c3
# Label:
# C=C1C(Oc2ccccc2C1=O)c3ccc4ccccc4c3
# Output:
# C=CCCCCc2ccccc2CCCcccccccccccccc4
# train tensor(116.4237, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(118.4641, device='cuda:0')
# Input:
# O=C(Nc1ccccc1)Nc2ccc3ccncc3c2
# Label:
# O=C(Nc1ccccc1)Nc2ccc3ccncc3c2
# Output:
# O=C(Nc1ccccc1ccccccccccccccc2
# train tensor(115.3261, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(119.7537, device='cuda:0')
# Input:
# OC(=O)CN1C(=S)N(Cc2ccc(Br)cc2F)c3ccc(Cl)cc3C1=O
# Label:
# OC(=O)CN1C(=S)N(Cc2ccc(Br)cc2F)c3ccc(Cl)cc3C1=O
# Output:
# OC(=O)C1CC(=O)N==cc2ccccc))ccccccccccccCCCC)O
# train tensor(114.6566, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(114.6342, device='cuda:0')
# Input:
# CCc1cccc2C(=NC(NC(=O)Nc3cccc(c3)c4nn[nH]n4)C(=O)N(CC(=O)N5CC6CCC(CC6)C5)c12)c7ccccc7F
# Label:
# CCc1cccc2C(=NC(NC(=O)Nc3cccc(c3)c4nn[nH]n4)C(=O)N(CC(=O)N5CC6CCC(CC6)C5)c12)c7ccccc7F
# Output:
# COc1ccc2CC======((ccccccccccccccccccccccccccccCCCCCCCCCCCCCCCCCCCCCCCCccccccccccccccc
# train tensor(114.0099, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(114.5956, device='cuda:0')
# Input:
# O=C1C2C3CS(=O)(=O)CC3C2C(=O)N1CCCCN4CCN(CC4)c5ncccn5
# Label:
# O=C1C2C3CS(=O)(=O)CC3C2C(=O)N1CCCCN4CCN(CC4)c5ncccn5
# Output:
# O=C1=CC=CCCCCCCOCCCCCCCCCCCCCCCCCCCCCCCCCccccccccc5
# train tensor(113.1243, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(115.2461, device='cuda:0')
# Input:
# CCC(C(CC)c1ccc(O)c(CC)c1)c2ccc(O)c(CC)c2
# Label:
# CCC(C(CC)c1ccc(O)c(CC)c1)c2ccc(O)c(CC)c2
# Output:
# CCC(C)CC)c1ccc(OccccCCCCccccccccccCCC)c2
# train tensor(112.3236, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(113.7177, device='cuda:0')
# Input:
# CN(Cc1ccc2ccccc2c1)c3cnc4nc(N)nc(N)c4n3
# Label:
# CN(Cc1ccc2ccccc2c1)c3cnc4nc(N)nc(N)c4n3
# Output:
# CN(Cc1cccccc2cccccccccccccccccccccccccc1
# train tensor(111.5321, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(117.1592, device='cuda:0')
# Input:
# CCN1CCC(C1)Oc2cccnc2
# Label:
# CCN1CCC(C1)Oc2cccnc2
# Output:
# CCN1CCCCCC)c2ccccc22
# train tensor(112.7260, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(113.1269, device='cuda:0')
# Input:
# OC(C(=O)OC1CN2CCC1CC2)(c3ccccc3)c4ccc(I)cc4
# Label:
# OC(C(=O)OC1CN2CCC1CC2)(c3ccccc3)c4ccc(I)cc4
# Output:
# OC(C(=O)C1CCCCCCCCCCCCcc3ccccc3ccccccccc)cc4
# train tensor(110.7744, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(112.3070, device='cuda:0')
# Input:
# COc1ccc2cc(ccc2c1)[C@H](C)C(=O)O
# Label:
# COc1ccc2cc(ccc2c1)[C@H](C)C(=O)O
# Output:
# COc1ccccccccccccc1[@@]]]]C==OOO
# train tensor(109.9234, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(111.6250, device='cuda:0')
# Input:
# COc1cc(cc(OC)c1OC(=O)C)[C@H]2[C@@H]3C(COC3=O)Cc4c(OC(=O)C)c5OCOc5cc24
# Label:
# COc1cc(cc(OC)c1OC(=O)C)[C@H]2[C@@H]3C(COC3=O)Cc4c(OC(=O)C)c5OCOc5cc24
# Output:
# COc1cc(cccOO)(=O)O[[@H]]CCCCCCCCCCCCCCCCCCCCCCCCCCCCCcccccOOOOccccc
# train tensor(110.2940, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(111.4865, device='cuda:0')
# Input:
# CC(C)[C@@H]1CCC[C@@H](C(C)C)C1OC(=O)NS(=O)(=O)Oc2c(cccc2C(C)C)C(C)C
# Label:
# CC(C)[C@@H]1CCC[C@@H](C(C)C)C1OC(=O)NS(=O)(=O)Oc2c(cccc2C(C)C)C(C)C
# Output:
# CC(C)[C@@]11CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC)ccccccccc22)CCCC(())
# train tensor(109.6809, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(110.9666, device='cuda:0')
# Input:
# CN(C)c1ncnc2c1ncn2Cc3ccc(cc3)[N+](=O)[O-]
# Label:
# CN(C)c1ncnc2c1ncn2Cc3ccc(cc3)[N+](=O)[O-]
# Output:
# CN(C)c1ccc(nc1nc2ccccccccc2)[[[]](=))[-]
# train tensor(109.2469, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(110.8617, device='cuda:0')
# Input:
# OC(=O)C=C1CCCCCC1
# Label:
# OC(=O)C=C1CCCCCC1
# Output:
# OC(=O)C1CCCCCCCCC1
# train tensor(108.1674, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(109.7222, device='cuda:0')
# Input:
# COc1ccc(cc1)C(=O)c2c3C(CCn3c4ccccc24)N5CCOCC5
# Label:
# COc1ccc(cc1)C(=O)c2c3C(CCn3c4ccccc24)N5CCOCC5
# Output:
# COc1ccc(cc1)C2CO)CcccccccccccccccccccCCCCCCCC
# train tensor(106.9400, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(109.4895, device='cuda:0')
# Input:
# COc1cc2CCN(C(=O)Nc3cc(cc(c3)c4cccnc4)c5ccccc5)c2cc1C(F)(F)F
# Label:
# COc1cc2CCN(C(=O)Nc3cc(cc(c3)c4cccnc4)c5ccccc5)c2cc1C(F)(F)F
# Output:
# COc1cc2CC(CO(=O)cccccccccccccccccccccccccccccccccc)))))(())F
# train tensor(106.0225, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(109.1432, device='cuda:0')
# Input:
# CCCc1cccc2nc(cc(O)c12)C(=O)O
# Label:
# CCCc1cccc2nc(cc(O)c12)C(=O)O
# Output:
# CCCc1ccccccccccccccc1)(==O)O
# train tensor(105.8497, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(108.5238, device='cuda:0')
# Input:
# CC(C)CCCC(C)C\C=C\C(=C\C(=O)NCC(C)C)\C
# Label:
# CC(C)CCCC(C)C\C=C\C(=C\C(=O)NCC(C)C)\C
# Output:
# CC(C)CCCC(C(CCCCCCCC=CCCC==OCCCCCCCCCC
# train tensor(105.3399, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(109.6083, device='cuda:0')
# Input:
# CC1=CC(=C2N1[B-](F)(F)[N+]1=C(C)C=C(C)C1=C2C1=CC=C(I)S1)C
# Label:
# CC1=CC(=C2N1[B-](F)(F)[N+]1=C(C)C=C(C)C1=C2C1=CC=C(I)S1)C
# Output:
# CC1=CC(=C)N==CCCCCCCC)))CCCCCCCCCCCCCCCCCCCCCCCCCCCC))CC
# train tensor(106.1773, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(110.5335, device='cuda:0')
# Input:
# OC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)c3ccccc3
# Label:
# OC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)c3ccccc3
# Output:
# OC(=O)[C@H](Cc1ccHH]cccccccccc11))OOcccccccc
# train tensor(103.8824, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(108.0342, device='cuda:0')
# Input:
# [Cl-].CCS(=O)(=O)CCOCn1cc[n+](C)c1\C=N\O
# Label:
# [Cl-].CCS(=O)(=O)CCOCn1cc[n+](C)c1\C=N\O
# Output:
# [Cl-].CC(=O)=O=====O)1ccccccc1CCCCCCNNO
# train tensor(104.6298, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(107.8410, device='cuda:0')
# Input:
# CCC(Oc1ccc(Cl)cc1C(=C)n2ccnc2)c3ccccc3
# Label:
# CCC(Oc1ccc(Cl)cc1C(=C)n2ccnc2)c3ccccc3
# Output:
# CCC(Oc1ccc(C)cccCCCCCCcccccc)cccccccc3
# train tensor(103.5156, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(107.0498, device='cuda:0')
# Input:
# CC1(C)O[C@@H]2CC[C@@]3(COS(=O)(=O)N)OC(C)(C)O[C@H]3[C@@H]2O1
# Label:
# CC1(C)O[C@@H]2CC[C@@]3(COS(=O)(=O)N)OC(C)(C)O[C@H]3[C@@H]2O1
# Output:
# CC1(C)O[C@@H]2CCCC@@](CCCCOOOOOOOCCCCCCCCCCCCCCCCCC[[@@@@]]
# train tensor(101.5733, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(106.9425, device='cuda:0')
# Input:
# CN(C)c1ccc2c(cc(nc2c1)N(C)C)N(C)C
# Label:
# CN(C)c1ccc2c(cc(nc2c1)N(C)C)N(C)C
# Output:
# CN(C)c1cc(cc1cccccc22)(CC()((())C
# train tensor(102.3272, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(110.9948, device='cuda:0')
# Input:
# CCCCCc1nccn1Cc2ccc(NC(=O)c3ccccc3C(=O)O)cc2
# Label:
# CCCCCc1nccn1Cc2ccc(NC(=O)c3ccccc3C(=O)O)cc2
# Output:
# CCCCCc1cc(ccc2ccccCCC=O)cc3ccccccC=OOcccc
# train tensor(102.9008, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(107.8313, device='cuda:0')
# Input:
# NC(=O)CCN1CCN(CCOC(c2ccccc2)c3ccccc3)CC1
# Label:
# NC(=O)CCN1CCN(CCOC(c2ccccc2)c3ccccc3)CC1
# Output:
# NC(=O)CCCCCCCCCCCCcc2ccccc2ccccccccccC1
# train tensor(101.0945, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(105.3861, device='cuda:0')
# Input:
# C\C(=C/c1ccc(cc1)C(=O)O)\c2ccc(cc2)C(C)(C)C
# Label:
# C\C(=C/c1ccc(cc1)C(=O)O)\c2ccc(cc2)C(C)(C)C
# Output:
# C\C(=C/c1cccccc1)((=O)OCcccccccc2CC((CC(()C
# train tensor(100.5507, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(107.4014, device='cuda:0')
# Input:
# CC(C)CC1NCCc2ccccc12
# Label:
# CC(C)CC1NCCc2ccccc12
# Output:
# CN(C)CCCCCCc2ccccc2C1
# train tensor(101.5088, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(105.5709, device='cuda:0')
# Input:
# CN(C\C=C\C(=O)OCc1ccccc1)Cc2cccc3ccccc23
# Label:
# CN(C\C=C\C(=O)OCc1ccccc1)Cc2cccc3ccccc23
# Output:
# C\(C\CCCC==C\==)c1ccccc1)c22cccccccccc33
# train tensor(99.3281, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(107.3290, device='cuda:0')
# Input:
# O=C(NC1CCN(C1)C#N)OCc2ccccc2
# Label:
# O=C(NC1CCN(C1)C#N)OCc2ccccc2
# Output:
# O=C(NC11CCCCCCCCCC))c2ccccc2
# train tensor(102.2587, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(108.3080, device='cuda:0')
# Input:
# CCC1CCN(C)c2cc3OC(=O)C=C(c3cc12)C(F)(F)F
# Label:
# CCC1CCN(C)c2cc3OC(=O)C=C(c3cc12)C(F)(F)F
# Output:
# CCC1CCN(C)c2cc(C(=OO((()cccccc2)))((())
# train tensor(101.7994, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(107.9403, device='cuda:0')
# Input:
# CC1=CN(C2OC(COP(=O)(O)C(F)(F)F)C=C2)C(=O)NC1=O
# Label:
# CC1=CN(C2OC(COP(=O)(O)C(F)(F)F)C=C2)C(=O)NC1=O
# Output:
# CC1=CC(C(CC(O(O(OO)(F))F))))))))))))(())))11
# train tensor(99.3198, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(104.0166, device='cuda:0')
# Input:
# CC#CC(=O)Nc1ccc(Cl)c(c1)c2oc3ccc(Cl)cc3n2
# Label:
# CC#CC(=O)Nc1ccc(Cl)c(c1)c2oc3ccc(Cl)cc3n2
# Output:
# CC(CC(=O)Nc1ccc(NC)cccccccccccccl)ccccn
# train tensor(97.9067, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(104.5777, device='cuda:0')
# Input:
# Clc1ccc(NC(=O)NCCN(c2ccccc2)c3ccccc3)cc1
# Label:
# Clc1ccc(NC(=O)NCCN(c2ccccc2)c3ccccc3)cc1
# Output:
# Clc1ccc(NC(=O)NCC=)cc2ccccc)cccccccccc1
# train tensor(97.9819, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(105.1423, device='cuda:0')
