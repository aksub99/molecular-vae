# %% [markdown]
# <a href="https://colab.research.google.com/github/aksub99/molecular-vae/blob/master/chembl%2BSF_100k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data
import gzip
import pandas
import h5py
import numpy as np
from __future__ import print_function
import argparse
import os
import h5py
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn import model_selection

# %%
def one_hot_array(i, n):
    return map(int, [ix == i for ix in xrange(n)])

def one_hot_index(vec, charset):
    return map(charset.index, vec)

def from_one_hot_array(vec):
    oh = np.where(vec == 1)
    if oh[0].shape == (0, ):
        return None
    return int(oh[0][0])

def decode_smiles_from_indexes(vec, charset):
    return "".join(map(lambda x: charset[x], vec)).strip()

def load_dataset(filename, split = True):
    h5f = h5py.File(filename, 'r')
    if split:
        data_train = h5f['data_train'][:]
    else:
        data_train = None
    data_test = h5f['data_test'][:]
    charset =  h5f['charset'][:]
    h5f.close()
    if split:
        return (data_train, data_test, charset)
    else:
        return (data_test, charset)

# %%
class MolecularVAE(nn.Module):
    def __init__(self):
        super(MolecularVAE, self).__init__()

        self.conv_1 = nn.Conv1d(120, 9, kernel_size=9)
        self.conv_2 = nn.Conv1d(9, 9, kernel_size=9)
        self.conv_3 = nn.Conv1d(9, 10, kernel_size=11)
        self.conv_4 = nn.Conv1d(10, 10, kernel_size=11)
        self.linear_0 = nn.Linear(160, 435)
        self.linear_1 = nn.Linear(435, 292)
        self.linear_2 = nn.Linear(435, 292)

        self.linear_3 = nn.Linear(292, 292)
        self.gru = nn.GRU(292, 501, 3, batch_first=True)
        self.linear_4 = nn.Linear(501, 52)
        
        self.relu = nn.ReLU()
        self.softmax = nn.Softmax()

    def encode(self, x):
        x = self.relu(self.conv_1(x))
        x = self.relu(self.conv_2(x))
        x = self.relu(self.conv_3(x))
        x = self.relu(self.conv_4(x))
        x = x.view(x.size(0), -1)
        x = F.selu(self.linear_0(x))
        return self.linear_1(x), self.linear_2(x)

    def sampling(self, z_mean, z_logvar):
        epsilon = 1e-2 * torch.randn_like(z_logvar)
        return torch.exp(0.5 * z_logvar) * epsilon + z_mean

    def decode(self, z):
        z = F.selu(self.linear_3(z))
        z = z.view(z.size(0), 1, z.size(-1)).repeat(1, 120, 1)
        output, hn = self.gru(z)
        out_reshape = output.contiguous().view(-1, output.size(-1))
        y0 = F.softmax(self.linear_4(out_reshape), dim=1)
        y = y0.contiguous().view(output.size(0), -1, y0.size(-1))
        return y

    def forward(self, x):
        z_mean, z_logvar = self.encode(x)
        z = self.sampling(z_mean, z_logvar)
        return self.decode(z), z_mean, z_logvar

def vae_loss(x_decoded_mean, x, z_mean, z_logvar):
    xent_loss = F.binary_cross_entropy(x_decoded_mean, x, size_average=False)
    kl_loss = -0.5 * torch.sum(1 + z_logvar - z_mean.pow(2) - z_logvar.exp())
    return xent_loss + kl_loss

# %%
# !rm -R 'molecular-vae'
# !git clone https://github.com/aksub99/molecular-vae.git
# import zipfile
# zip_ref = zipfile.ZipFile('molecular-vae/data/processed.zip', 'r')
# zip_ref.extractall('molecular-vae/data/')
# zip_ref.close()

# !git clone https://aksub99:Ajak1999@github.com/aksub99/FissionNet.git

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
data_train, data_test, charset = load_dataset('drive/My Drive/chembl+SF_100k/chembl_singlet_processed_100k.h5')
data_train = torch.utils.data.TensorDataset(torch.from_numpy(data_train))
train_loader = torch.utils.data.DataLoader(data_train, batch_size=250, shuffle=True)

data_test = torch.utils.data.TensorDataset(torch.from_numpy(data_test))
test_loader = torch.utils.data.DataLoader(data_test, batch_size=250, shuffle=True)

print(charset)
print(len(charset))

torch.manual_seed(42)

epochs = 90
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# [' ' '#' '%' ')' '(' '+' '-' '/' '.' '1' '0' '3' '2' '5' '4' '7' '6' '9'
#  '8' '=' 'A' '@' 'C' 'B' 'F' 'I' 'H' 'K' 'L' 'O' 'N' 'P' 'S' 'T' 'V' '['
#  'Z' ']' '\\' 'a' 'c' 'b' 'e' 'g' 'i' 'l' 'o' 'n' 'p' 's' 'r' 't']
# 52

# %%
model = MolecularVAE().to(device)
optimizer = optim.Adam(model.parameters())

# %%
def train(epoch):
    model.train()
    train_loss = 0
    for batch_idx, data in enumerate(train_loader):
        data = data[0].to(device)
        optimizer.zero_grad()
        output, mean, logvar = model(data)
        
        if batch_idx==0:
              inp = data.cpu().numpy()
              outp = output.cpu().detach().numpy()
              lab = data.cpu().numpy()
              print("Input:")
              print(decode_smiles_from_indexes(map(from_one_hot_array, inp[0]), charset))
              print("Label:")
              print(decode_smiles_from_indexes(map(from_one_hot_array, lab[0]), charset))
              sampled = outp[0].reshape(1, 120, len(charset)).argmax(axis=2)[0]
              print("Output:")
              print(decode_smiles_from_indexes(sampled, charset))
        
        loss = vae_loss(output, data, mean, logvar)
        loss.backward()
        train_loss += loss
        optimizer.step()
#         if batch_idx % 100 == 0:
#             print(f'{epoch} / {batch_idx}\t{loss:.4f}')
    print('train', train_loss / len(train_loader.dataset))
    return train_loss / len(train_loader.dataset)
  
def test(epoch):
  with torch.no_grad():
      test_loss = 0.0
      for batch_idx, data in enumerate(test_loader):
          data = data[0].to(device)
          output, mean, logvar = model(data)
          loss = vae_loss(output, data, mean, logvar)
          test_loss += loss
      print('test', test_loss / len(test_loader.dataset))
      return test_loss / len(test_loader.dataset)

# %%
import matplotlib.pyplot as plt

train_loss_values = []
test_loss_values = []
for epoch in range(1, epochs + 1):
    train_loss = train(epoch)
    test_loss = test(epoch)
    train_loss_values.append(train_loss)
    test_loss_values.append(test_loss)
    if epoch % 5 == 0:
        plt.plot(np.array(train_loss_values), 'r')
        plt.plot(np.array(test_loss_values), 'b')
    if epoch % 2 == 0:
        torch.save(model.state_dict(), "drive/My Drive/chembl+SF_100k/chembl+SF_100k_{}.pth".format(epoch))
# Out:
# Input:
# COC(=O)C1Cc2c([nH]c3ccccc23)C(N1)c4ccc(C)cc4
# Label:
# COC(=O)C1Cc2c([nH]c3ccccc23)C(N1)c4ccc(C)cc4
# Output:
# ##iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii
# /usr/local/lib/python2.7/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# train tensor(197.3937, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(173.5947, device='cuda:0')
# Input:
# CCCc1nc(CC)c(C(=O)OCCCC(=O)Nc2ccccc2)n1Cc3ccc(cc3F)c4ccccc4S(=O)(=O)NC(=O)OCCC(C)C
# Label:
# CCCc1nc(CC)c(C(=O)OCCCC(=O)Nc2ccccc2)n1Cc3ccc(cc3F)c4ccccc4S(=O)(=O)NC(=O)OCCC(C)C
# Output:
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCcccccccccccccccccccccccccc
# train tensor(173.0054, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(182.0294, device='cuda:0')
# Input:
# Clc1ccc(Cl)c2C[C@@H](CCc12)N3CCC4(CC3)N(CNC4=O)c5ccccc5
# Label:
# Clc1ccc(Cl)c2C[C@@H](CCc12)N3CCC4(CC3)N(CNC4=O)c5ccccc5
# Output:
# CCCCCCCCCCCCCCCCCCCCcccccccccccccccccccccccccccccccccccccc
# train tensor(166.8880, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(164.4480, device='cuda:0')
# Input:
# CC(C)C1(O)[C@@H](OC(=O)c2ccc[nH]2)C3(O)[C@@]4(C)CC5(O)OC6([C@H](OC(=O)CCNC(=O)OCc7ccccc7)C(C)CCC46O)C3(O)C15C
# Label:
# CC(C)C1(O)[C@@H](OC(=O)c2ccc[nH]2)C3(O)[C@@]4(C)CC5(O)OC6([C@H](OC(=O)CCNC(=O)OCc7ccccc7)C(C)CCC46O)C3(O)C15C
# Output:
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCcccccccccccccc
# train tensor(166.2943, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(165.2733, device='cuda:0')
# Input:
# COc1ccc2cccc3C[C@@H](Cc1c23)NC(=O)C
# Label:
# COc1ccc2cccc3C[C@@H](Cc1c23)NC(=O)C
# Output:
# CCCCCccccccCCCCCCCCCCCCCCCCCCCCCC
# train tensor(163.7028, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(162.6159, device='cuda:0')
# Input:
# CCc1cccc2C(=O)c3ccccc3Sc12
# Label:
# CCc1cccc2C(=O)c3ccccc3Sc12
# Output:
# CC11ccccccccccccccccccccc
# train tensor(164.4063, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(162.1485, device='cuda:0')
# Input:
# OC(=O)[C@@H](Cc1ccccc1)NC(=O)c2ccccc2
# Label:
# OC(=O)[C@@H](Cc1ccccc1)NC(=O)c2ccccc2
# Output:
# CC1Ccccccccccccccccccccccccccccccccc
# train tensor(161.3497, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(157.9511, device='cuda:0')
# Input:
# COc1cc2N([C@@H](O)[C@@H]3CCCN3C(=O)c2cc1OC)C(=O)OCCS(=O)(=O)c4ccccc4
# Label:
# COc1cc2N([C@@H](O)[C@@H]3CCCN3C(=O)c2cc1OC)C(=O)OCCS(=O)(=O)c4ccccc4
# Output:
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCccccccccccccccccccc
# train tensor(157.6212, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(156.9472, device='cuda:0')
# Input:
# Cc1ccc(cc1)C(c2ccn(c2)c3ccc(Cl)cc3)n4ccnc4
# Label:
# Cc1ccc(cc1)C(c2ccn(c2)c3ccc(Cl)cc3)n4ccnc4
# Output:
# Ccccccccccccccccccccccccccccccccccccccccc
# train tensor(157.1167, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(158.6630, device='cuda:0')
# Input:
# CCOC(=O)N(C)C(=O)C(CC)(OCc1ccccc1)c2ccccc2
# Label:
# CCOC(=O)N(C)C(=O)C(CC)(OCc1ccccc1)c2ccccc2
# Output:
# CCCCCCCCCCCCCCCCCCCCCCccccccccccccccccc
# train tensor(153.0732, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(151.2338, device='cuda:0')
# Input:
# O[C@@H]1[C@@H](CCc2ccccc2)N(Cc3ccc(F)c(c3)C#N)C(=O)N(Cc4ccc(F)c(c4)C#N)[C@@H]1Cc5ccccc5
# Label:
# O[C@@H]1[C@@H](CCc2ccccc2)N(Cc3ccc(F)c(c3)C#N)C(=O)N(Cc4ccc(F)c(c4)C#N)[C@@H]1Cc5ccccc5
# Output:
# CC(CCCCCCCCCCCCCcccccccccCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCccccccccccccccccccccccccccc
# train tensor(151.4543, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(149.0672, device='cuda:0')
# Input:
# Br.Br.CCCCCCCCCCN=C1C=CN(CCCCCCCCCCCCN2C=CC(=NCCCCCCCCCC)C=C2)C=C1
# Label:
# Br.Br.CCCCCCCCCCN=C1C=CN(CCCCCCCCCCCCN2C=CC(=NCCCCCCCCCC)C=C2)C=C1
# Output:
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# train tensor(148.2841, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(145.7150, device='cuda:0')
# Input:
# COC(=O)c1cc2oc1C[C@H](C[C@H](OC(=O)C)[C@@]34O[C@@H]3[C@@H](C[C@]5(C)O[C@@H]25)OC4=O)C(=C)C=O
# Label:
# COC(=O)c1cc2oc1C[C@H](C[C@H](OC(=O)C)[C@@]34O[C@@H]3[C@@H](C[C@]5(C)O[C@@H]25)OC4=O)C(=C)C=O
# Output:
# CCCCC)CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# train tensor(145.5067, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(144.3190, device='cuda:0')
# Input:
# Fc1ccccc1C2=NC(NC(=O)Nc3ccc(Cl)cc3)C(=O)Nc4ccccc24
# Label:
# Fc1ccccc1C2=NC(NC(=O)Nc3ccc(Cl)cc3)C(=O)Nc4ccccc24
# Output:
# Cc1cccccccccccccccccccccccccccccccccccccccccccccc
# train tensor(143.8314, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(141.5953, device='cuda:0')
# Input:
# CN(C)CCN1C(=O)c2ccc(c3cc4ccccc4c(C1=O)c23)S(=O)(=O)C
# Label:
# CN(C)CCN1C(=O)c2ccc(c3cc4ccccc4c(C1=O)c23)S(=O)(=O)C
# Output:
# CC(CCCCCCCCC)ccccccccccccccccccccccc)))CCCCCCCC==OO
# train tensor(140.5881, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(139.5089, device='cuda:0')
# Input:
# CC(C)OC(=O)OC(C)OC(=O)C1=C(S[C@@H]2CCO[C@@H]2CNC(=O)OCOC(=O)C(C)C)[C@H](C)C3[C@@H]([C@@H](C)O)C(=O)N13
# Label:
# CC(C)OC(=O)OC(C)OC(=O)C1=C(S[C@@H]2CCO[C@@H]2CNC(=O)OCOC(=O)C(C)C)[C@H](C)C3[C@@H]([C@@H](C)O)C(=O)N13
# Output:
# CC(C)))CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# train tensor(139.4881, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(138.7971, device='cuda:0')
# Input:
# Nc1ccc(cc1)C(=O)NCCNCC(O)COc2cccc3OCCOc23
# Label:
# Nc1ccc(cc1)C(=O)NCCNCC(O)COc2cccc3OCCOc23
# Output:
# Cc1ccc(cc11ccCCCCCCCCCCCCCCCCcccccccccccc
# train tensor(136.6756, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(135.7819, device='cuda:0')
# Input:
# C[C@H](NC(=O)C[C@@H](CC(=O)O)C(=O)O)[C@@H](Cc1ccc(Cl)c(Cl)c1)c2ccc(c(F)c2)c3ccccc3
# Label:
# C[C@H](NC(=O)C[C@@H](CC(=O)O)C(=O)O)[C@@H](Cc1ccc(Cl)c(Cl)c1)c2ccc(c(F)c2)c3ccccc3
# Output:
# C[C@@H]]CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC))))cccccccccccccccccccccccccccccc
# train tensor(134.3648, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(132.5171, device='cuda:0')
# Input:
# OC(=O)CC[C@H](NC(=O)Nc1ccc(COC(=O)Nc2ccccc2N(CCBr)CCBr)cc1)C(=O)O
# Label:
# OC(=O)CC[C@H](NC(=O)Nc1ccc(COC(=O)Nc2ccccc2N(CCBr)CCBr)cc1)C(=O)O
# Output:
# CC(=O)CC@@@H(CCCCCCOCcccccccccC))CCCCcccccccccccccccccCCCCCCOOO
# train tensor(131.7530, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(130.6292, device='cuda:0')
# Input:
# CC(C)(C(O)\C=C\c1ccc(cc1)C(=N)N)C(=O)N2CCC(CC(=O)O)CC2
# Label:
# CC(C)(C(O)\C=C\c1ccc(cc1)C(=N)N)C(=O)N2CCC(CC(=O)O)CC2
# Output:
# CC(C)CCCCCCCCcc1ccccccccccCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# train tensor(129.9726, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(127.1508, device='cuda:0')
# Input:
# CCS(=O)(=O)CCC1=C(O)N(Cc2ccccc2)c3nc4N(C)C(=O)N(C)C(=O)c4n3C1=O
# Label:
# CCS(=O)(=O)CCC1=C(O)N(Cc2ccccc2)c3nc4N(C)C(=O)N(C)C(=O)c4n3C1=O
# Output:
# CC(=O)(CCCCCCCCCCCCCCCcc2cccccccccccccccccccCCCCCCCCCCCCCCCCO
# train tensor(127.4903, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(136.0667, device='cuda:0')
# Input:
# COc1cc(Cc2cnc(N)nc2N)cc(C#CCCCC(=O)O)c1OC
# Label:
# COc1cc(Cc2cnc(N)nc2N)cc(C#CCCCC(=O)O)c1OC
# Output:
# COc1ccc(NccccccccccccccCCCCCCCCCCCCO))C
# train tensor(124.8233, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(125.9426, device='cuda:0')
# Input:
# C(Cc1ccccc1)[C@H]2CCCC[C@@H]2NC3=NCCO3
# Label:
# C(Cc1ccccc1)[C@H]2CCCC[C@@H]2NC3=NCCO3
# Output:
# CCCc1cccccc1[@@@H2CCCCCCCCCCCCCCCCC3
# train tensor(122.4619, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(120.5869, device='cuda:0')
# Input:
# COc1ccccc1N2CCN(CCN3N=C(c4ccccc4)c5c(C)onc5C3=O)CC2
# Label:
# COc1ccccc1N2CCN(CCN3N=C(c4ccccc4)c5c(C)onc5C3=O)CC2
# Output:
# COc1ccccc11NCCCCCCCCCCCCCccccccccccccccccCCCCCCCCCC
# train tensor(121.7516, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(127.9293, device='cuda:0')
# Input:
# COc1cc(ccc1Cc2cn(Cc3cccc(c3)C#N)c4ccc(NC(=O)CC5CCCC5)cc24)C(=O)NS(=O)(=O)C
# Label:
# COc1cc(ccc1Cc2cn(Cc3cccc(c3)C#N)c4ccc(NC(=O)CC5CCCC5)cc24)C(=O)NS(=O)(=O)C
# Output:
# COc1ccc(cc1)c2ccccccccccccccccccccccccccccccCCCCCCCCCCCCCCCCCCCCCCCCC)CC
# train tensor(119.9779, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(121.3776, device='cuda:0')
# Input:
# CSCC[C@H](NC(=O)c1cccc(CN(Cc2ccc(cc2)C#N)Cc3cncn3Cc4ccc(cc4)C#N)c1)C(=O)O
# Label:
# CSCC[C@H](NC(=O)c1cccc(CN(Cc2ccc(cc2)C#N)Cc3cncn3Cc4ccc(cc4)C#N)c1)C(=O)O
# Output:
# CCCC[C@H](CCC=O)c1ccccccccccccccccccccccccccccccccccccccccccccccc)CC))))
# train tensor(118.0473, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(117.1814, device='cuda:0')
# Input:
# C(COc1nn2c(nnc2c3ccccc13)c4ccccc4)Cc5ccccc5
# Label:
# C(COc1nn2c(nnc2c3ccccc13)c4ccccc4)Cc5ccccc5
# Output:
# C(Cc1nncccccccccccccccccccccccccccccccccccc
# train tensor(116.7213, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(116.6165, device='cuda:0')
# Input:
# NC1=NC(=O)N(C=C1I)[C@@H]2CS[C@H](CO)O2
# Label:
# NC1=NC(=O)N(C=C1I)[C@@H]2CS[C@H](CO)O2
# Output:
# NC1=NC(=O)N(N)CC[[[@@H]][CC@@@CCCC)OO
# train tensor(114.9144, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(115.1381, device='cuda:0')
# Input:
# CC(C)C[C@H](NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(=O)CF
# Label:
# CC(C)C[C@H](NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(=O)CF
# Output:
# CC(C)C[C@@H](NC(=O)OCCOOCCCCCCCCOOOcccccccccc1CCCCCO)O
# train tensor(114.0534, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(113.9996, device='cuda:0')
# Input:
# O=C1CC2(CCCC2)CC(=O)N1CCN3CCN(CC3)c4ncccc4C#N
# Label:
# O=C1CC2(CCCC2)CC(=O)N1CCN3CCN(CC3)c4ncccc4C#N
# Output:
# O=C1CCCCCCCCCCCCCCCCCCCCCCCCCCCCCN)c4cccccc4
# train tensor(112.9950, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(114.1270, device='cuda:0')
# Input:
# CC(C)(Oc1ccc(cc1)N2CCN(CC2)c3ccc(cc3)C(=N)N)C(=O)O
# Label:
# CC(C)(Oc1ccc(cc1)N2CCN(CC2)c3ccc(cc3)C(=N)N)C(=O)O
# Output:
# CC(C)(Occ1cccccc1CC(CCCCCCcccccccccc)C====CCC()CN
# train tensor(111.1025, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(111.3215, device='cuda:0')
# Input:
# CN1CC23Cc4ccc(O)cc4C(C)(CCC12)C3
# Label:
# CN1CC23Cc4ccc(O)cc4C(C)(CCC12)C3
# Output:
# CN1CC(CCc3ccc()cccc3CCCCCCCCCC1
# train tensor(110.2169, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(110.2392, device='cuda:0')
# Input:
# O=C1Nc2cc(ccc2/C/1=C/c3[nH]cc4C(=O)OCCc34)c5ccccc5
# Label:
# O=C1Nc2cc(ccc2/C/1=C/c3[nH]cc4C(=O)OCCc34)c5ccccc5
# Output:
# O=C(Nc1ccc2ccccc1cCCCCCCccccccccccCCOOOcccccccccc5
# train tensor(109.3006, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(113.4142, device='cuda:0')
# Input:
# c1ccc(cc1)N=C=Nc1ccccc1
# Label:
# c1ccc(cc1)N=C=Nc1ccccc1
# Output:
# Bc1ccccc1NNNNNNc2ccccc2
# train tensor(108.4437, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(108.9771, device='cuda:0')
# Input:
# C[C@@H]1CCN[C@H]([C@H]1C(=O)CP(=O)(O)O)C(=O)O
# Label:
# C[C@@H]1CCN[C@H]([C@H]1C(=O)CP(=O)(O)O)C(=O)O
# Output:
# C[C@@H]1CC[C@@H](CC@@H](OO)O)OOOOOOOO))(OOOO
# train tensor(106.8817, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(107.3365, device='cuda:0')
# Input:
# Oc1ccc2C(=O)\C(=C\c3ccncc3)\Cc2c1
# Label:
# Oc1ccc2C(=O)\C(=C\c3ccncc3)\Cc2c1
# Output:
# Oc1ccc2C(=O)\CCCCcc3cccccc)C)ccc1
# train tensor(106.8912, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(109.3212, device='cuda:0')
# Input:
# NCCCC[C@@H]1NC(=O)C[S+]([O-])C[C@H](NC(=O)[C@H](CC(=O)O)NC(=O)CNC(=O)[C@H](CCCN=C(N)N)NC1=O)C(=O)O
# Label:
# NCCCC[C@@H]1NC(=O)C[S+]([O-])C[C@H](NC(=O)[C@H](CC(=O)O)NC(=O)CNC(=O)[C@H](CCCN=C(N)N)NC1=O)C(=O)O
# Output:
# NCCCCCCC@H]CCC==O)NCCOO)CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC))O(==))OO
# train tensor(104.9533, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(111.0336, device='cuda:0')
# Input:
# Cc1cc(C)cc(c1)c2c(O)nc3cc(Cl)c(NC(=O)c4cnccn4)cc3c2OCC[C@@H]5CCCCN5
# Label:
# Cc1cc(C)cc(c1)c2c(O)nc3cc(Cl)c(NC(=O)c4cnccn4)cc3c2OCC[C@@H]5CCCCN5
# Output:
# Cn1cc(C)cccc1)cc2c(O)cccccccccccccC))CCCCCCCCcccccccCCCCCCCCCCCCCCCC
# train tensor(105.2471, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(107.3505, device='cuda:0')
# Input:
# CC(C)COC(=O)N[C@@H](Cc1c[nH]c2ccccc12)C(=O)NCCc3ccccc3
# Label:
# CC(C)COC(=O)N[C@@H](Cc1c[nH]c2ccccc12)C(=O)NCCc3ccccc3
# Output:
# CC(C)CC(=O)O[C@@H](CC11[nH]ccccccccc2)CCCOOOOcccccccc3
# train tensor(103.7259, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(104.7047, device='cuda:0')
# Input:
# CN(C)c1nc(nc2c1ncn2Cc3ccc(Cl)c(NC=O)c3)C(F)(F)F
# Label:
# CN(C)c1nc(nc2c1ncn2Cc3ccc(Cl)c(NC=O)c3)C(F)(F)F
# Output:
# CN(C)c1nc(nc2ccncc2cc3cccc(CCCC((()))))(FFFFFFF
# train tensor(101.8976, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(104.8485, device='cuda:0')
# Input:
# CN1CC[C@H]([C@@H](C1)c2onc(n2)c3ccc(Br)cc3)c4ccc(Cl)cc4
# Label:
# CN1CC[C@H]([C@@H](C1)c2onc(n2)c3ccc(Br)cc3)c4ccc(Cl)cc4
# Output:
# CN1CC[C@@]][C@@H](())ccccc()ccccccccccccccccccccccc)ccc
# train tensor(101.0219, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(104.0860, device='cuda:0')
# Input:
# CC(=O)N1N=C(CC1c2cccc(Cl)c2)c3ccc(O)cc3
# Label:
# CC(=O)N1N=C(CC1c2cccc(Cl)c2)c3ccc(O)cc3
# Output:
# CC(=O)NNCCC(CCCc2ccccc2CC(O)3cccc(()cc3
# train tensor(102.0929, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(105.7328, device='cuda:0')
# Input:
# CC\C(=C/1\Oc2ccc(F)cc2c3ccc4NC(C)(C)C=C(C)c4c13)\C
# Label:
# CC\C(=C/1\Oc2ccc(F)cc2c3ccc4NC(C)(C)C=C(C)c4c13)\C
# Output:
# CC\C==C//1c2ccc(FcccccccccccCCC(((CCCCCCCCC))))cc
# train tensor(98.6487, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(101.1231, device='cuda:0')
# Input:
# CC(C)CCC(=O)[C@H](CC1CCCCC1)NC(=O)[C@H](CC(C)C)NC(=O)Cc2ccccc2
# Label:
# CC(C)CCC(=O)[C@H](CC1CCCCC1)NC(=O)[C@H](CC(C)C)NC(=O)Cc2ccccc2
# Output:
# CC(C)CCCC(O)[C@H](CCCCCCCCCCCCCCC@@@CCCCCCCCCCCCCCC))cccccccccc
# train tensor(98.6703, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(102.3474, device='cuda:0')
# Input:
# CN1CCN(CC1)NC(=O)Oc2ccc(Cl)cc2
# Label:
# CN1CCN(CC1)NC(=O)Oc2ccc(Cl)cc2
# Output:
# CN1CCN(CC1))((=O)c2ccc(Cl)cc22
# train tensor(99.6257, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(101.1840, device='cuda:0')
# Input:
# COc1ccc2ccc3[nH]c4c(cccc4c3c2c1)c5ccccc5
# Label:
# COc1ccc2ccc3[nH]c4c(cccc4c3c2c1)c5ccccc5
# Output:
# COc1ccc2c(3[nH]]ccccccccccccccccccccccc
# train tensor(97.0665, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(100.5072, device='cuda:0')
# Input:
# C[C@@H](NC(=O)c1c(C)nc(c2ccc(Cl)cc2)n1C)[C@](O)(Cn3cncn3)c4ccc(F)cc4F
# Label:
# C[C@@H](NC(=O)c1c(C)nc(c2ccc(Cl)cc2)n1C)[C@](O)(Cn3cncn3)c4ccc(F)cc4F
# Output:
# C[C@@H](NC(=O)c1cc(cc1)c2ccc()l))))CCCCCC(((CCnnncccccccccccccccc44
# train tensor(97.4205, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(100.5827, device='cuda:0')
# Input:
# CO[C@H]1CN(CC(=C)Cl)C[C@H](OCC23C[C@@H]4[C@H](C)CC[C@H]4C5(CC2C=C(C(C)C)C35C(=O)O)C=O)O[C@@H]1C
# Label:
# CO[C@H]1CN(CC(=C)Cl)C[C@H](OCC23C[C@@H]4[C@H](C)CC[C@H]4C5(CC2C=C(C(C)C)C35C(=O)O)C=O)O[C@@H]1C
# Output:
# CO[C@H]1CCCCCCCCCCCCCC[@@@]]CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# train tensor(95.8725, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(102.2895, device='cuda:0')
# Input:
# CS(=O)(=O)c1cc(ccc1Oc2cccnc2)C(=O)N=C(N)N
# Label:
# CS(=O)(=O)c1cc(ccc1Oc2cccnc2)C(=O)N=C(N)N
# Output:
# CS(=O)(=O)c1ccc(cc1)c2ccc(c2)C(==))CC=)CN
# train tensor(97.1387, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(102.4506, device='cuda:0')
# Input:
# COC(C)C1CCC=C(C1)\C=N\O
# Label:
# COC(C)C1CCC=C(C1)\C=N\O
# Output:
# COC(C)CCCCCCCCCCCCCC==O
# train tensor(95.9106, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(100.8012, device='cuda:0')
# Input:
# CCCCCCCCCC[C@@H](O)[C@@H]1CC[C@@H](O1)[C@H](O)CC[C@H](O)[C@@H]2CC[C@@H](CCCCCCC[C@@H](O)CC3=C[C@H](C)OC3=O)O2
# Label:
# CCCCCCCCCC[C@@H](O)[C@@H]1CC[C@@H](O1)[C@H](O)CC[C@H](O)[C@@H]2CC[C@@H](CCCCCCC[C@@H](O)CC3=C[C@H](C)OC3=O)O2
# Output:
# CCCCCCCCCC[C@@H](OCC@@H](CCC@@H]]CCCCC@H]]2CCCCCHH]CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC=
# train tensor(95.0364, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(99.2839, device='cuda:0')
# Input:
# O=C(CN1CC(=O)NC1=O)Nc2c3CCCCc3nc4ccccc24
# Label:
# O=C(CN1CC(=O)NC1=O)Nc2c3CCCCc3nc4ccccc24
# Output:
# O=C(CNNCC==O)N1=O=O)c2CCCCCC33ccccccccc4
# train tensor(92.6501, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(98.1600, device='cuda:0')
# Input:
# CCOC(=O)COc1ccc(C(=O)c2ccc(O)c(c2)C(=O)O)c(Cl)c1Cl
# Label:
# CCOC(=O)COc1ccc(C(=O)c2ccc(O)c(c2)C(=O)O)c(Cl)c1Cl
# Output:
# CCOC(=O)COcccc(CC=OOc2ccc(O))((((O))ccccc)))))))
# train tensor(92.4668, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(98.8449, device='cuda:0')
# Input:
# CCCCCOC(=O)NS(=O)(=O)c1ccccc1c2ccc(Cn3c(CCC)nc(CC)c3C(=O)OCCC(=O)Nc4ccccc4)c(F)c2
# Label:
# CCCCCOC(=O)NS(=O)(=O)c1ccccc1c2ccc(Cn3c(CCC)nc(CC)c3C(=O)OCCC(=O)Nc4ccccc4)c(F)c2
# Output:
# CCCCOCC==O)NS(=O)(=Occccccc1ccccc((cCCCCCCCCCCCCCCCcccccCCCCCCCCccccccccccccccccc
# train tensor(91.9694, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(96.8243, device='cuda:0')
# Input:
# Cc1c(NS(=O)(=O)C)cccc1N(Cc2ccccc2)Cc3ccccc3C(F)(F)F
# Label:
# Cc1c(NS(=O)(=O)C)cccc1N(Cc2ccccc2)Cc3ccccc3C(F)(F)F
# Output:
# Cc1c(NS(=O)(=O)C)cccc1NCcc2ccccc2)c3cccccc3c)FFFFFFF
# train tensor(93.2367, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(101.1890, device='cuda:0')
# Input:
# COc1cccc(COc2ccc(cc2)C3=NN(CCC#N)C(=O)O3)c1
# Label:
# COc1cccc(COc2ccc(cc2)C3=NN(CCC#N)C(=O)O3)c1
# Output:
# COc1cccc(COc2ccc(cc2)C(=NNCCCCCCCCCCOOOO)c11
# train tensor(91.2007, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(111.3891, device='cuda:0')
# Input:
# CCN(CC)CCC[C@@H](C)Nc1c2CCCCc2nc3CCCCc13
# Label:
# CCN(CC)CCC[C@@H](C)Nc1c2CCCCc2nc3CCCCc13
# Output:
# CCN(CC)CCC[C@@H](1CCc2cc(CCCCCCcccCCCC)cc22
# train tensor(92.6381, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(96.9846, device='cuda:0')
# Input:
# CCCC\N=C(/N)\Nc1nc(cs1)c2ccc(CNC(=O)C)s2
# Label:
# CCCC\N=C(/N)\Nc1nc(cs1)c2ccc(CNC(=O)C)s2
# Output:
# CCCC\N=C(/N)NNc1ccc(1))cccccc22CC(OCCCC
# train tensor(89.8629, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(96.5614, device='cuda:0')
# Input:
# Cc1cc(OCc2ccc(cc2)c3ccccc3c4nn[nH]n4)c(C(=O)O)c(C)n1
# Label:
# Cc1cc(OCc2ccc(cc2)c3ccccc3c4nn[nH]n4)c(C(=O)O)c(C)n1
# Output:
# Cc1cc(CCc2ccc(c22)c3ccccc3c4n[[H]()((((())))C(((cc
# train tensor(90.4134, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(99.4628, device='cuda:0')
# Input:
# CCCCCCCCCCCCCCCCNCc1ccc(cc1)C(=O)O
# Label:
# CCCCCCCCCCCCCCCCNCc1ccc(cc1)C(=O)O
# Output:
# CCCCCCCCCCCCCCCCCNc1ccc(cc1)C(=O)OC
# train tensor(89.9260, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(99.4213, device='cuda:0')
# Input:
# Oc1ccc(cc1)C(=C2CC3CCC2C3)c4ccc(O)cc4
# Label:
# Oc1ccc(cc1)C(=C2CC3CCC2C3)c4ccc(O)cc4
# Output:
# Oc1ccc(cc1)C(=O)CCCCCCCCCcccccc(O)cc4
# train tensor(89.0394, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(95.7982, device='cuda:0')
# Input:
# Clc1cc(ccc1S(=O)(=O)N(CC=C)CC=C)N2N=CC(=O)NC2=O
# Label:
# Clc1cc(ccc1S(=O)(=O)N(CC=C)CC=C)N2N=CC(=O)NC2=O
# Output:
# Clc1cc(cc1)S(=O)(=O)NCCCCCCCCCCCCCCCCCCCC=NN=O
# train tensor(88.0004, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(94.3459, device='cuda:0')
# Input:
# NC(=N)NCCC[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=O)C[S+]([O-])C[C@H](NC(=O)[C@H](CC(=O)O)NC(=O)CNC1=O)C(=O)O
# Label:
# NC(=N)NCCC[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=O)C[S+]([O-])C[C@H](NC(=O)[C@H](CC(=O)O)NC(=O)CNC1=O)C(=O)O
# Output:
# NC(=N)NCCC[C@@H]1NC(=O)[C@H](Cc2ccc(c)cc)))(((((())]C]]]]]]]]CCCCCCCCCCCCCCCCCCCC)))))))))OOOOO))(((OOO
# train tensor(88.3892, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(99.4284, device='cuda:0')
# Input:
# OP(=O)(O)C(NC1CC1)P(=O)(O)O
# Label:
# OP(=O)(O)C(NC1CC1)P(=O)(O)O
# Output:
# OP(=O)(O)C(CCCCC)1PP=O)(O)
# train tensor(88.3133, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(93.5668, device='cuda:0')
# Input:
# CCCN(CCC)C1CCc2cccc(C#N)c2C1
# Label:
# CCCN(CCC)C1CCc2cccc(C#N)c2C1
# Output:
# CCCN(CCC)C1CCc2cccc(CCcc21
# train tensor(91.3503, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(97.6063, device='cuda:0')
# Input:
# Fc1ccc(cc1)S(=O)(=O)N2CCN(CC2)C(=O)c3ccc(Nc4ccnc5cc(ccc45)C(F)(F)F)cc3
# Label:
# Fc1ccc(cc1)S(=O)(=O)N2CCN(CC2)C(=O)c3ccc(Nc4ccnc5cc(ccc45)C(F)(F)F)cc3
# Output:
# Fc1ccc(cc1)S(=O)(=O)C2CCCCCCCC==))ccccccccccccccccccccccccc))FFFF))FF
# train tensor(88.6192, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(96.5529, device='cuda:0')
# Input:
# Clc1ccc(Cl)c(c1)S(=O)(=O)N2CC(CCc3ccccc3)N(Cc4c[nH]cn4)c5ccccc5C2
# Label:
# Clc1ccc(Cl)c(c1)S(=O)(=O)N2CC(CCc3ccccc3)N(Cc4c[nH]cn4)c5ccccc5C2
# Output:
# Clc1ccc(CC)ccc1)((=O)(=O)NCCC]](cc3ccccccccccccccccccccccccccccc5
# train tensor(89.5688, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(94.3572, device='cuda:0')
# Input:
# COc1cc2CCN(C(=O)Nc3cncc(c3)c4ccccc4)c2cc1C(F)(F)F
# Label:
# COc1cc2CCN(C(=O)Nc3cncc(c3)c4ccccc4)c2cc1C(F)(F)F
# Output:
# COc1cc2CCN(C(=O)Nc3cccccc)ccccccc))ccccc111CF))))FF
# train tensor(92.3210, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(92.2689, device='cuda:0')
# Input:
# COc1cc(NS(=O)(=O)C)ccc1Nc2c3ccccc3nc4cc(N)ccc24
# Label:
# COc1cc(NS(=O)(=O)C)ccc1Nc2c3ccccc3nc4cc(N)ccc24
# Output:
# COc1cc(NS(=O)(=O)C)ccc1Nc2c3ccccc3cc4cc(ccccc22
# train tensor(86.8859, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(94.1059, device='cuda:0')
# Input:
# COc1ccccc1CC\N=C(/N)\Nc2nc(cs2)c3oc(CNC(=O)C)cn3
# Label:
# COc1ccccc1CC\N=C(/N)\Nc2nc(cs2)c3oc(CNC(=O)C)cn3
# Output:
# COc1ccccc1\C\C\//NNNN\c2ccc22ccNN(((CCC))(ccccCC
# train tensor(85.5173, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(92.7311, device='cuda:0')
# Input:
# ClCCN(N=O)C(=O)Oc1cccnc1
# Label:
# ClCCN(N=O)C(=O)Oc1cccnc1
# Output:
# ClCCNC(=O)C(=O)n1ccccn1
# train tensor(87.2147, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(93.1160, device='cuda:0')
# Input:
# Clc1nc(NC(=O)c2cccc(I)c2)c3ncn(C4CCCO4)c3n1
# Label:
# Clc1nc(NC(=O)c2cccc(I)c2)c3ncn(C4CCCO4)c3n1
# Output:
# Clc1nc(CC(=O)c2ccccc(C))cccccCCCCCCCCC)nn1
# train tensor(84.8463, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(91.0441, device='cuda:0')
# Input:
# Cc1ccc(c2ccc(cc2)S(=O)(=O)C)n1C3CCCCC3
# Label:
# Cc1ccc(c2ccc(cc2)S(=O)(=O)C)n1C3CCCCC3
# Output:
# Cc1ccc(c2cccccc2)S(=O)(=O)))CCCCCCCCC3
# train tensor(85.3037, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(94.7029, device='cuda:0')
# Input:
# C[C@@]12CCCN1C[C@@H](c3ccccc3)c4ccccc24
# Label:
# C[C@@]12CCCN1C[C@@H](c3ccccc3)c4ccccc24
# Output:
# C[C@@]12CCCCCC[[C@@H]c3ccccc3)ccccccc24
# train tensor(85.2916, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(114.6844, device='cuda:0')
# Input:
# C[C@H]1CCC[C@H](\C=C/[C@@H]2[C@H]3CCCC[C@@H]3C[C@H]4[C@@H]2[C@H](C)OC4=O)N1C
# Label:
# C[C@H]1CCC[C@H](\C=C/[C@@H]2[C@H]3CCCC[C@@H]3C[C@H]4[C@@H]2[C@H](C)OC4=O)N1C
# Output:
# C[C@H]11CCCCCCCCCCCCC@@@@CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# train tensor(87.2365, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(92.0551, device='cuda:0')
# Input:
# Oc1oc(CCN2CCN(CC2)c3cc(Cl)ccc3Cl)c(n1)c4ccc(F)cc4
# Label:
# Oc1oc(CCN2CCN(CC2)c3cc(Cl)ccc3Cl)c(n1)c4ccc(F)cc4
# Output:
# Oc1nc(CCN2CCN(CC))c3cc((l))cccl))cc)))ccccc(F))cc4
# train tensor(83.9705, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(90.1308, device='cuda:0')
# Input:
# CC(C)(n1ccnc1)n2ccnc2
# Label:
# CC(C)(n1ccnc1)n2ccnc2
# Output:
# CC(C)n11nccn12ncccc22
# train tensor(83.1222, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(91.2973, device='cuda:0')
# Input:
# Oc1ccc(cc1)c2nc(c3ccc(F)cc3)c([nH]2)c4ccncc4
# Label:
# Oc1ccc(cc1)c2nc(c3ccc(F)cc3)c([nH]2)c4ccncc4
# Output:
# Oc1ccc(cc1)c2nc(cccc2)c3ccc)cc[HH]]cc4ccccc4
# train tensor(95.8929, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(105.5317, device='cuda:0')
# Input:
# CCCCN(C\C=C\C#CC(C)(C)C)c1cccc2NC(=O)CCc12
# Label:
# CCCCN(C\C=C\C#CC(C)(C)C)c1cccc2NC(=O)CCc12
# Output:
# CCCCN\CCCCCCCCCCCCCCCCCCcc1cccccCCC==OC))111
# train tensor(84.8527, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(97.6915, device='cuda:0')
# Input:
# CCCN1CC[C@H]2[C@H]1CCc3c(OC)cccc23
# Label:
# CCCN1CC[C@H]2[C@H]1CCc3c(OC)cccc23
# Output:
# CCCN1CC[C@H]2[C@H]CCCccOOO)cccc2
# train tensor(85.1675, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(93.7913, device='cuda:0')
# Input:
# CCCCCCCCOC(=O)c1ccc(COC(COCc2ccc(OC)cc2)Cn3ccnc3)cc1
# Label:
# CCCCCCCCOC(=O)c1ccc(COC(COCc2ccc(OC)cc2)Cn3ccnc3)cc1
# Output:
# CCCCCCCC(C(=O)c1ccc(OCC(())c2ccccCCcccccccccccccccc
# train tensor(82.4216, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(91.3295, device='cuda:0')
# Input:
# O=C1CC2OCC=C3CN4CC[C@@]56[C@@H]4C[C@@H]3[C@@H]2C5N1c7ccccc67
# Label:
# O=C1CC2OCC=C3CN4CC[C@@]56[C@@H]4C[C@@H]3[C@@H]2C5N1c7ccccc67
# Output:
# O=C1CC2(COCCCCCCC[C@@H]1[[C@H]]C[[@@@H]CCCCC@CCCCCcccccccccccc
# train tensor(82.1076, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(89.7716, device='cuda:0')
# Input:
# CCCC(=O)Nc1ccc2C(=O)C(=O)c3ccccc3c2c1
# Label:
# CCCC(=O)Nc1ccc2C(=O)C(=O)c3ccccc3c2c1
# Output:
# CCCC(=O)Nc1ccc2C(=O)C(=O)c3ccccc3)cc
# train tensor(82.5737, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(96.9400, device='cuda:0')
# Input:
# Cc1cnnn1C2CN3CCC2CC3
# Label:
# Cc1cnnn1C2CN3CCC2CC3
# Output:
# Cc1nncnn22C3NCCC22CC33
# train tensor(83.5931, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(91.1184, device='cuda:0')
# Input:
# CCCCCC\N=C(/N)\NCCC(=O)O
# Label:
# CCCCCC\N=C(/N)\NCCC(=O)O
# Output:
# CCCCCCNN=(/()NCCCC(=O)O
# train tensor(83.9725, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(92.6406, device='cuda:0')
# Input:
# C[C@H](NC(=O)[C@H](N)CC#C)C(=O)O.OC(=O)C(F)(F)F
# Label:
# C[C@H](NC(=O)[C@H](N)CC#C)C(=O)O.OC(=O)C(F)(F)F
# Output:
# C[C@H](NC(=O)[C@H](CCCCCCCCC(=OOOOO)))))))))(FF
# train tensor(82.6945, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(89.6725, device='cuda:0')
# Input:
# CCCCC(C)(C)[C@H](O)\C=C\[C@H]1[C@H](O)C[C@H](O)[C@@H]1C\C=C/CCCC(=O)O
# Label:
# CCCCC(C)(C)[C@H](O)\C=C\[C@H]1[C@H](O)C[C@H](O)[C@@H]1C\C=C/CCCC(=O)O
# Output:
# CCCCC(CC)C[[C@H](OC\\\C[[@@H]1[[C@H]]CCCC@HH]CCCC@HHCCCCCCCCCCCC(=OOO
# train tensor(81.2348, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(88.7864, device='cuda:0')
# Input:
# CCCc1nc(CC)c(C(=O)OCc2ccccc2C(=O)c3ccccc3)n1Cc4ccc(cc4F)c5ccccc5S(=O)(=O)NC(=O)OCC(C)C
# Label:
# CCCc1nc(CC)c(C(=O)OCc2ccccc2C(=O)c3ccccc3)n1Cc4ccc(cc4F)c5ccccc5S(=O)(=O)NC(=O)OCC(C)C
# Output:
# CCCc1nc(CC)c(C(=O)O)c2ccccc2))Cc3c3ccccccccccc4ccccccccccccccccccc(((OOOOOOOOOCCCCCCC
# train tensor(81.2934, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(95.9494, device='cuda:0')
# Input:
# CN(Cc1cc(cc(c1)C(F)(F)F)C(F)(F)F)C(=O)C(c2ccccc2)c3ccccc3
# Label:
# CN(Cc1cc(cc(c1)C(F)(F)F)C(F)(F)F)C(=O)C(c2ccccc2)c3ccccc3
# Output:
# CN(C)cc1cccccc1))(F)FF)FFFFFFFFF((((((())ccccccc2ccccccc3
# train tensor(82.9489, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(110.2725, device='cuda:0')
# Input:
# CCCCCCCCCCCCOS(=O)(=O)NC(=O)Oc1c(cccc1C(C)C)C(C)C
# Label:
# CCCCCCCCCCCCOS(=O)(=O)NC(=O)Oc1c(cccc1C(C)C)C(C)C
# Output:
# CCCCCCCCCCCCOC(=O)(=O)(=(==O)ccccccccc1CCCCCCCCCCCCC
# train tensor(83.5479, device='cuda:0', grad_fn=<DivBackward0>)
# test tensor(98.0102, device='cuda:0')

# %%
model = MolecularVAE().to(device)
model.load_state_dict(torch.load("drive/My Drive/chembl+SF/chembl+SF_120.pth"))
optimizer = optim.Adam(model.parameters())
epochs = 30
